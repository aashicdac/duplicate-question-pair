# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("E:\\Projects\\nlp_project\\dataset_duplicat_question\\train.csv")
df.shape
# Out:
# (404290, 6)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 27735    27735   51500   51501
# 235600  235600  346352  346353
# 396534  396534  529597  529598
# 121402  121402  196733  196734
# 67308    67308  116511  116512
# 57954    57954    1893    4121
# 78463    78463  133785  133786
# 139328  139328  198690  221663
# 42707    42707   76920   76921
# 254155  254155  140581  132922
#
#                                                 question1  \
# 27735   Where else can you work as a pilot besides the...
# 235600  What is the worst / harshest prison in the Uni...
# 396534  What's a good book to learn 9th and 10th grade...
# 121402  If I end an accidental messenger call in less ...
# 67308   What is the best arrangement of 2/3 monitors f...
# 57954   Why is Saltwater taffy candy imported in Austr...
# 78463   If there ever was a Bengali version of Batman ...
# 139328  Why do I feel tired in the morning even after ...
# 42707   How do I choose between IPR AND ADR as my opti...
# 254155  How does Trump's win affects Indian students p...
#
#                                                 question2  is_duplicate
# 27735   Where can I go to fly the kind of simulators u...             0
# 235600     What is it like to be a woman in state prison?             0
# 396534         How do child prodigies learn math so fast?             0
# 121402  How long do you have to cancel a WhatsApp call...             0
# 67308   What is the best software traffic monitor use ...             0
# 57954     Why is Saltwater taffy candy imported in Japan?             1
# 78463   If there ever was a Bollywood version of Batma...             0
# 139328                Why I feel so tired after sleeping?             1
# 42707   What is the logic behind the outside inside ou...             0
# 254155  How will Trump's presidency affect the Indian ...             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
# missing values
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Distribution of duplicate and non-duplicate questions
print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>
